# %% [markdown]
# # Model #1

# %%
# Import our dependencies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestRegressor

# %%
# Transform a time series dataset into a supervised learning dataset
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    cols = list()
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
    for i in range(0, n_out):
        cols.append(df.shift(-i))
    agg = pd.concat(cols, axis=1)
    if dropnan:
        agg.dropna(inplace=True)
    return agg.values

# %%
# split a univariate dataset into train/test sets
def train_test_split(data, n_test):
    return data[:-n_test, :], data[-n_test:, :]

# %%
# fit an random forest model and make a one step prediction
def random_forest_forecast(train, testX):
    train = np.asarray(train)
    trainX, trainy = train[:, :-1], train[:, -1]
    model = RandomForestRegressor(n_estimators=1000)
    model.fit(trainX, trainy)
    yhat = model.predict([testX])
    return yhat[0]

# %%
# Validation for univariate data
from sklearn.metrics import mean_absolute_error
def walk_forward_validation(data, n_test):
    predictions = list()
    train, test = train_test_split(data, n_test)
    history = [x for x in train]
    for i in range(len(test)):
        testX, testy = test[i, :-1], test[i, -1]
        yhat = random_forest_forecast(history, testX)
        predictions.append(yhat)
        history.append(test[i])
        print('>expected=%.1f, predicted=%.1f' % (testy, yhat))
    error = mean_absolute_error(test[:, -1], predictions)
    return error, test[:, -1], predictions

# %%
# load the dataset
series = pd.read_csv('Resources/crypto_details_target.csv', header=0, index_col=0)

values = series.values

# transform the time series data into supervised learning
data = series_to_supervised(values, n_in=6)
data
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_151608\1718532589.py in <module>
#       5
#       6 # transform the time series data into supervised learning
# ----> 7 data = series_to_supervised(values, n_in=6)
#       8 data
#
# ~\AppData\Local\Temp\ipykernel_151608\2647657679.py in series_to_supervised(data, n_in, n_out, dropnan)
#      10     agg = pd.concat(cols, axis=1)
#      11     if dropnan:
# ---> 12         agg.dropna(inplace=True)
#      13     return agg.values
#
# ~\anaconda3\envs\mlenv\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\envs\mlenv\lib\site-packages\pandas\core\frame.py in dropna(self, axis, how, thresh, subset, inplace)
#    5968                 raise TypeError("must specify how or thresh")
#    5969
# -> 5970         result = self.loc(axis=axis)[mask]
#    5971
#    5972         if inplace:
#
# ~\anaconda3\envs\mlenv\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     929
#     930             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 931             return self._getitem_axis(maybe_callable, axis=axis)
#     932
#     933     def _is_scalar_access(self, key: tuple):
#
# ~\anaconda3\envs\mlenv\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1142             return self._get_slice_axis(key, axis=axis)
#    1143         elif com.is_bool_indexer(key):
# -> 1144             return self._getbool_axis(key, axis=axis)
#    1145         elif is_list_like_indexer(key):
#    1146
#
# ~\anaconda3\envs\mlenv\lib\site-packages\pandas\core\indexing.py in _getbool_axis(self, key, axis)
#     948         key = check_bool_indexer(labels, key)
#     949         inds = key.nonzero()[0]
# --> 950         return self.obj._take_with_is_copy(inds, axis=axis)
#     951
#     952
#
# ~\anaconda3\envs\mlenv\lib\site-packages\pandas\core\generic.py in _take_with_is_copy(self, indices, axis)
#    3626         See the docstring of `take` for full explanation of the parameters.
#    3627         """
# -> 3628         result = self.take(indices=indices, axis=axis)
#    3629         # Maybe set copy if we didn't actually change the index.
#    3630         if not result._get_axis(axis).equals(self._get_axis(axis)):
#
# ~\anaconda3\envs\mlenv\lib\site-packages\pandas\core\generic.py in take(self, indices, axis, is_copy, **kwargs)
#    3611         nv.validate_take((), kwargs)
#    3612
# -> 3613         self._consolidate_inplace()
#    3614
#    3615         new_data = self._mgr.take(
#
# ~\anaconda3\envs\mlenv\lib\site-packages\pandas\core\generic.py in _consolidate_inplace(self)
#    5563             self._mgr = self._mgr.consolidate()
#    5564
# -> 5565         self._protect_consolidate(f)
#    5566
#    5567     @final
#
# ~\anaconda3\envs\mlenv\lib\site-packages\pandas\core\generic.py in _protect_consolidate(self, f)
#    5551             return f()
#    5552         blocks_before = len(self._mgr.blocks)
# -> 5553         result = f()
#    5554         if len(self._mgr.blocks) != blocks_before:
#    5555             self._clear_item_cache()
#
# ~\anaconda3\envs\mlenv\lib\site-packages\pandas\core\generic.py in f()
#    5561
#    5562         def f():
# -> 5563             self._mgr = self._mgr.consolidate()
#    5564
#    5565         self._protect_consolidate(f)
#
# ~\anaconda3\envs\mlenv\lib\site-packages\pandas\core\internals\managers.py in consolidate(self)
#     617         bm = type(self)(self.blocks, self.axes, verify_integrity=False)
#     618         bm._is_consolidated = False
# --> 619         bm._consolidate_inplace()
#     620         return bm
#     621
#
# ~\anaconda3\envs\mlenv\lib\site-packages\pandas\core\internals\managers.py in _consolidate_inplace(self)
#     622     def _consolidate_inplace(self) -> None:
#     623         if not self.is_consolidated():
# --> 624             self.blocks = tuple(_consolidate(self.blocks))
#     625             self._is_consolidated = True
#     626             self._known_consolidated = True
#
# ~\anaconda3\envs\mlenv\lib\site-packages\pandas\core\internals\managers.py in _consolidate(blocks)
#    1973     for (_can_consolidate, dtype), group_blocks in grouper:
#    1974         merged_blocks = _merge_blocks(
# -> 1975             list(group_blocks), dtype=dtype, can_consolidate=_can_consolidate
#    1976         )
#    1977         new_blocks = extend_blocks(merged_blocks, new_blocks)
#
# ~\anaconda3\envs\mlenv\lib\site-packages\pandas\core\internals\managers.py in _merge_blocks(blocks, dtype, can_consolidate)
#    1999             # Sequence[Union[int, float, complex, str, bytes, generic]],
#    2000             # Sequence[Sequence[Any]], SupportsArray]]
# -> 2001             new_values = np.vstack([b.values for b in blocks])  # type: ignore[misc]
#    2002         else:
#    2003             bvals = [blk.values for blk in blocks]
#
# <__array_function__ internals> in vstack(*args, **kwargs)
#
# ~\anaconda3\envs\mlenv\lib\site-packages\numpy\core\shape_base.py in vstack(tup)
#     280     if not isinstance(arrs, list):
#     281         arrs = [arrs]
# --> 282     return _nx.concatenate(arrs, 0)
#     283
#     284
#
# <__array_function__ internals> in concatenate(*args, **kwargs)
#
# MemoryError: Unable to allocate 2.68 GiB for an array with shape (91, 3948480) and data type object

# %% [markdown]
# # Model #2

# %%
# Import the dependency
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score
import warnings
warnings.filterwarnings('ignore')

# %%
# Loading the dataset
crypto_details_df = pd.read_csv("Resources/crypto_details_target.csv")
crypto_details_df.head(10)
# Out:
#    Unnamed: 0   timestamp                 date  Asset_ID    Asset_Name  \
# 0           0  1592697660  2020-06-21 00:01:00         1       Bitcoin
# 1           1  1592697660  2020-06-21 00:01:00        11        Monero
# 2           2  1592697660  2020-06-21 00:01:00         5        EOS.IO
# 3           3  1592697660  2020-06-21 00:01:00         0  Binance Coin
# 4           4  1592697660  2020-06-21 00:01:00         9      Litecoin
# 5           5  1592697660  2020-06-21 00:01:00         6      Ethereum
# 6           6  1592697720  2020-06-21 00:02:00        11        Monero
# 7           7  1592697720  2020-06-21 00:02:00         9      Litecoin
# 8           8  1592697720  2020-06-21 00:02:00         6      Ethereum
# 9           9  1592697720  2020-06-21 00:02:00         0  Binance Coin
#
#      Weight  Count        Volume         Open         High        Low  \
# 0  6.779922  504.0     15.768265  9364.227143  9378.100000  9359.9800
# 1  1.609438    6.0     23.654590    64.090000    64.110000    64.0900
# 2  1.386294  435.0  80796.575643     2.540683     2.547300     2.5387
# 3  4.304065   22.0    290.890000    16.068600    16.077500    16.0682
# 4  2.397895  125.0    738.758489    43.651500    43.670000    43.6400
# 5  5.894403  424.0   1300.092998   229.055000   229.459933   228.9100
# 6  1.609438   12.0     63.852110    64.120000    64.120000    64.1000
# 7  2.397895   36.0    118.165684    43.661000    43.680000    43.6400
# 8  5.894403  289.0    239.642529   229.134596   229.437578   229.0100
# 9  4.304065   46.0    481.530000    16.067300    16.072600    16.0648
#
#          Close         VWAP    Target
# 0  9366.225714  9365.439427 -0.000791
# 1    64.110000    64.093652 -0.002652
# 2     2.542350     2.542050 -0.002344
# 3    16.069700    16.070634  0.005875
# 4    43.657500    43.656948 -0.000662
# 5   229.154989   229.136591 -0.000949
# 6    64.110000    64.107327 -0.003044
# 7    43.667200    43.664316 -0.000395
# 8   229.161263   229.138053 -0.000677
# 9    16.066900    16.068496  0.003569

# %%
# Asset_ID = 1 for Bitcoin
btc = crypto_details_df[crypto_details_df["Asset_ID"]==1].set_index("timestamp")
btc.info(show_counts =True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 658080 entries, 1592697660 to 1632182400
# Data columns (total 13 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Unnamed: 0  658080 non-null  int64
#  1   date        658080 non-null  object
#  2   Asset_ID    658080 non-null  int64
#  3   Asset_Name  658080 non-null  object
#  4   Weight      658080 non-null  float64
#  5   Count       658080 non-null  float64
#  6   Volume      658080 non-null  float64
#  7   Open        658080 non-null  float64
#  8   High        658080 non-null  float64
#  9   Low         658080 non-null  float64
#  10  Close       658080 non-null  float64
#  11  VWAP        658080 non-null  float64
#  12  Target      658080 non-null  float64
# dtypes: float64(9), int64(2), object(2)
# memory usage: 70.3+ MB

# %%
# Check the timestamp difference between consecutive rows to see if there is missing data.
(btc.index[1:]-btc.index[:-1]).value_counts().head()
# Out:
# 60    658079
# Name: timestamp, dtype: int64

# %% [markdown]
# ## Overview of the Data

# %%
# Check the shape
print(f'Shape of Dataframe {btc.shape}')
# Out:
# Shape of Dataframe (658080, 13)

# %%
btc.describe()
# Out:
#          Unnamed: 0  Asset_ID        Weight          Count         Volume  \
# count  6.580800e+05  658080.0  6.580800e+05  658080.000000  658080.000000
# mean   1.974240e+06       1.0  6.779922e+00    2098.830978     101.630036
# std    1.139829e+06       0.0  2.166535e-11    2234.224683     146.515788
# min    0.000000e+00       1.0  6.779922e+00       1.000000       0.000500
# 25%    9.871210e+05       1.0  6.779922e+00     894.000000      38.181776
# 50%    1.974239e+06       1.0  6.779922e+00    1525.000000      63.630681
# 75%    2.961357e+06       1.0  6.779922e+00    2510.000000     111.647561
# max    3.948474e+06       1.0  6.779922e+00   87478.000000    5990.868930
#
#                 Open           High            Low          Close  \
# count  658080.000000  658080.000000  658080.000000  658080.000000
# mean    31356.794270   31402.821670   31313.075779   31356.854642
# std     17177.712772   17200.478947   17153.715314   17177.707000
# min      8856.158750    8896.800000    8812.800000    8860.687291
# 25%     11824.261184   11838.000000   11813.937883   11824.223737
# 50%     33533.012381   33585.148433   33490.000000   33533.639512
# 75%     47089.410000   47146.000000   47030.437500   47089.755833
# max     64805.943750   64900.000000   64670.530000   64808.537275
#
#                 VWAP         Target
# count  658080.000000  658080.000000
# mean    31356.590653      -0.000009
# std     17177.527440       0.002192
# min      8857.758372      -0.072556
# 25%     11824.385605      -0.000919
# 50%     33534.756690      -0.000046
# 75%     47088.192163       0.000825
# max     64799.822215       0.089280

# %%
btc['Close'].plot(grid=True, figsize=(12,8))
plt.xlabel('Time')
plt.ylabel('Close Price')
# Out:
# Text(0, 0.5, 'Close Price')

# %%
# Candlestick chart
btc = crypto_details_df[crypto_details_df["Asset_ID"]==1].set_index("timestamp") # Asset_ID = 1 for Bitcoin
btc_mini = btc.iloc[-200:] # Select recent data rows

import plotly.graph_objects as go

fig = go.Figure(data=[go.Candlestick(x=btc_mini.index, open=btc_mini['Open'], high=btc_mini['High'], low=btc_mini['Low'], close=btc_mini['Close'])])
fig.show()
# Out:
# <div>                            <div id="a9e2a3bf-8dc1-46da-96b5-887c0606f9ee" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a9e2a3bf-8dc1-46da-96b5-887c0606f9ee")) {                    Plotly.newPlot(                        "a9e2a3bf-8dc1-46da-96b5-887c0606f9ee",                        [{"close":[43447.00375,43440.0,43360.72375,43427.24285714286,43375.04,43391.2775,43328.33142857143,43333.292857142864,43272.20571428572,43302.26142857143,43237.22857142857,43293.438571428575,43335.397142857146,43329.36,43315.57857142857,43358.98,43401.56125,43496.01714285714,43543.944285714286,43735.24749999998,43635.8,43565.93714285714,43445.9742505125,43582.882500000014,43509.89375,43583.13375,43620.45625000002,43683.955,43688.792857142864,43748.37285714286,43733.61857142858,43770.91142857143,43725.21247342,43699.93519433285,43681.41125,43663.37142857142,43674.12714285714,43735.2968762825,43761.40857142857,43804.98142857143,43748.64871729857,43754.64400535857,43761.9313146925,43745.054649555714,43749.41395637714,43704.05428571429,43754.37857142858,43752.16000000002,43752.56428571429,43742.16285714285,43722.25010413143,43698.399835418575,43678.80153424286,43688.29428571429,43673.78428571428,43674.93714285714,43696.93209772,43696.218571428566,43688.90142857142,43680.15714285715,43699.02571428572,43731.86428571429,43747.49428571429,43762.66571428572,43851.00774273375,43796.60571428571,43767.107142857145,43685.150000000016,43691.55,43724.642857142855,43737.69285714287,43651.975714285705,43596.42285714286,43623.89428571428,43635.89571428572,43561.85142857144,43536.07792585572,43480.374285714286,43514.82,43608.34571428572,43568.90142857143,43554.05285714286,43631.01714285714,43631.90714285714,43537.49,43597.75303396001,43648.514285714286,43697.334285714285,43707.43,43726.24681658715,43765.792857142864,43715.65571428572,43715.125714285714,43710.31428571429,43731.00625,43770.145714285725,43814.85571428571,43816.27125000001,43806.570000000014,43806.79142857143,43770.66857142857,43799.1,43833.474285714285,43811.704285714295,43843.44,43832.01571428571,43786.38571428572,43769.188571428575,43774.467142857146,43796.19,43797.20571428572,43798.15714285714,43804.61142857144,43831.59142857143,43871.69625,43897.16857142858,43901.38285714285,43883.25895342144,43862.52,43894.77857142857,43866.73499999999,43845.84857142857,43823.298571428575,43752.76714285714,43703.374285714286,43669.07857142857,43642.77285714285,43615.38,43504.42428571429,43367.88571428572,43316.7225,43295.04428571429,43250.16571428572,43075.9025,43232.90125,43259.1575,43293.7075,43305.09857142857,43327.79,43356.28068103,43344.55857142858,43484.61375,43580.82375,43470.794999999984,43198.788571428566,43213.69,43269.54714285715,43239.26125,43114.23614144125,43067.63,43060.81,42991.2775,42989.62375,43219.33125,43140.19135458125,43198.24000000001,43110.797500000015,43157.72298172143,43099.1575,43051.08285714287,42966.91285714286,43009.43142857143,42880.67875,42822.040000000015,42699.178750000014,42778.885,42779.71,42700.44625,42659.58241635572,42600.39625,42624.279999999984,42577.0,42679.60625,42678.21816655625,42762.514285714286,42825.295,42736.6525,42769.39571428571,42637.115,42703.63625,42781.97057111125,42755.5925,42717.23428571428,42657.20249999999,42678.72142857143,42778.29125,42790.17571428571,42731.73142857143,42898.565,42939.64571428572,42927.167142857135,42979.83375,42960.60142857144,42985.48285714286,42985.21482412572,42899.01285714287,42860.00571428572,42827.02,43017.277142857136,43002.505],"high":[43588.68,43495.95402838,43455.2184781,43454.99,43467.0,43405.0,43407.7,43350.0,43344.99,43315.99,43317.0,43318.8,43353.43,43363.82,43341.56,43372.8,43436.99,43512.7,43581.88,43750.27,43749.6,43636.4,43587.1,43609.1,43617.0,43611.11,43634.01,43715.6675949,43 ...

# %% [markdown]
# ## Exploratory Data Analysis

# %%
# Distribution of Open and Close prices, the Highest and Lowest prices
btc_eda=btc.drop(['Unnamed: 0','date','Asset_ID','Asset_Name','Weight','Count','Volume'],axis=1)
btc_eda.hist(bins=50,figsize=(12,8))
# Out:
# array([[<AxesSubplot:title={'center':'Open'}>,
#         <AxesSubplot:title={'center':'High'}>],
#        [<AxesSubplot:title={'center':'Low'}>,
#         <AxesSubplot:title={'center':'Close'}>],
#        [<AxesSubplot:title={'center':'VWAP'}>,
#         <AxesSubplot:title={'center':'Target'}>]], dtype=object)

# %%
# a univariate distribution plot is drawn to show the marginal distribution of the data in each column.
sns.pairplot(data=btc_eda)

# %% [markdown]
# ## Correlation

# %%
corr= btc_eda.corr()
sns.heatmap(corr,annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Preprocessing the Data

# %%
# Scaling the data
scaler = StandardScaler()
scaler.fit(btc_eda.drop(['Target'],axis=1))
# Out:
# StandardScaler()

# %%
# Define the features set.
X=np.array(scaler.transform(btc_eda.drop(['Target'],axis=1)))

# %%
# Define the target set.
y= np.array(btc_eda['Target'])

# %% [markdown]
# ## Split the Data

# %%
# Splitting into Train and Test sets.
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=1)

# %%
print(f'shape of X_train : {X_train.shape}\nshape of X_test : {X_test.shape}\nshape of y_train : {y_train.shape}\nshape of y_test : {y_test.shape}')
# Out:
# shape of X_train : (526464, 5)
# shape of X_test : (131616, 5)
# shape of y_train : (526464,)
# shape of y_test : (131616,)

# %% [markdown]
# ## Random Forest Regression

# %%
modelEns = RandomForestRegressor()
modelEns.fit(X_train,y_train)
Y_predEns = modelEns.predict(X_test)

# %%
print("MSE : ",mean_absolute_error(y_test, Y_predEns))
print("MAE : ",mean_squared_error(y_test,Y_predEns))
print("R2_Score: ",r2_score(y_test,Y_predEns))
# Out:
# MSE :  0.0014012184841727473
# MAE :  5.013768507124221e-06
# R2_Score:  -0.0405932607770616

# %%
btc_pred = pd.DataFrame({"Real Prediction":y_test,"Model Prediction":Y_predEns})
btc_pred.head(10)
# Out:
#    Real Prediction  Model Prediction
# 0         0.000049         -0.001758
# 1        -0.000119         -0.000625
# 2         0.000224          0.000348
# 3        -0.003773         -0.000251
# 4         0.000052         -0.000020
# 5        -0.000177          0.000611
# 6        -0.002617         -0.000645
# 7        -0.000318         -0.000727
# 8         0.000464         -0.000149
# 9         0.000324         -0.000847

# %%
btc_pred.plot(grid=True, figsize=(12,8))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Preprocessing the Data

# %%
# Scaling the data
scaler = StandardScaler()
scaler.fit(btc_eda.drop(['Close'],axis=1))
# Out:
# StandardScaler()

# %%
# Define the features set.
X=np.array(scaler.transform(btc_eda.drop(['Close'],axis=1)))

# %%
# Define the target set.
y= np.array(btc_eda['Close'])

# %% [markdown]
# ## Split the Data

# %%
# Splitting into Train and Test sets.
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=1)

print(f'shape of X_train : {X_train.shape}\nshape of X_test : {X_test.shape}\nshape of y_train : {y_train.shape}\nshape of y_test : {y_test.shape}')
# Out:
# shape of X_train : (526464, 5)
# shape of X_test : (131616, 5)
# shape of y_train : (526464,)
# shape of y_test : (131616,)

# %% [markdown]
# ## Random Forest Regression

# %%
modelEns = RandomForestRegressor()
modelEns.fit(X_train,y_train)
Y_predEns = modelEns.predict(X_test)

# %%
print("MSE : ",mean_absolute_error(y_test, Y_predEns))
print("MAE : ",mean_squared_error(y_test,Y_predEns))
print("R2_Score: ",r2_score(y_test,Y_predEns))
# Out:
# MSE :  10.130203472909873
# MAE :  362.0882805332602
# R2_Score:  0.9999987706418366

# %%
btc_pred2 = pd.DataFrame({"Real Prediction":y_test,"Model Prediction":Y_predEns})
btc_pred2.head(10)
# Out:
#    Real Prediction  Model Prediction
# 0     34809.205714      34814.195264
# 1     23230.781823      23229.459974
# 2      9109.742857       9108.733847
# 3     18069.033183      18066.427449
# 4     19045.843333      19048.330639
# 5     61050.320000      61066.186187
# 6     40423.785714      40426.524674
# 7     47105.628571      47085.050142
# 8     12793.430000      12793.890750
# 9     45633.197143      45656.627550

# %%
btc_pred2.plot(grid=True)
# Out:
# <AxesSubplot:>

# %%
from sklearn.metrics import balanced_accuracy_score
from sklearn.metrics import confusion_matrix
from imblearn.metrics import classification_report_imbalanced

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler,OneHotEncoder
import pandas as pd
import tensorflow as tf


#  Import and read the train.csv.
import pandas as pd 
crypto_df = pd.read_csv("train.csv")
crypto_df
# Out:
#            timestamp  Asset_ID  Count          Open          High  \
# 0         1514764860         2   40.0   2376.580000   2399.500000
# 1         1514764860         0    5.0      8.530000      8.530000
# 2         1514764860         1  229.0  13835.194000  14013.800000
# 3         1514764860         5   32.0      7.659600      7.659600
# 4         1514764860         7    5.0     25.920000     25.920000
# ...              ...       ...    ...           ...           ...
# 24236801  1632182400         9  775.0    157.181571    157.250000
# 24236802  1632182400        10   34.0   2437.065067   2438.000000
# 24236803  1632182400        13  380.0      0.091390      0.091527
# 24236804  1632182400        12  177.0      0.282168      0.282438
# 24236805  1632182400        11   48.0    232.695000    232.800000
#
#                    Low         Close        Volume          VWAP    Target
# 0          2357.140000   2374.590000  1.923301e+01   2373.116392 -0.004218
# ...

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler,OneHotEncoder
import pandas as pd
import tensorflow as tf


#  Import and read the train.csv.
import pandas as pd 
crypto2_df = pd.read_csv("asset_details.csv")
crypto2_df
# Out:
#     Asset_ID    Weight        Asset_Name
# 0          2  2.397895      Bitcoin Cash
# 1          0  4.304065      Binance Coin
# 2          1  6.779922           Bitcoin
# 3          5  1.386294            EOS.IO
# 4          7  2.079442  Ethereum Classic
# 5          6  5.894403          Ethereum
# 6          9  2.397895          Litecoin
# 7         11  1.609438            Monero
# 8         13  1.791759              TRON
# 9         12  2.079442           Stellar
# 10         3  4.406719           Cardano
# 11         8  1.098612              IOTA
# 12        10  1.098612             Maker
# 13         4  3.555348          Dogecoin

# %%
# Merge the two DataFrames together and drop the Country column
merge_crypto_df = crypto_df.merge(crypto2_df,left_index=True,right_index=True)

# %%
# Drop the null columns where all values are null
new_crypto_df = merge_crypto_df.dropna(axis='columns', how='all')

# %%
# Drop the null rows
new_crypto_df = new_crypto_df.dropna()

new_crypto_df
# Out:
#      timestamp  Asset_ID_x  Count          Open        High         Low  \
# 0   1514764860           2   40.0   2376.580000   2399.5000   2357.1400
# 1   1514764860           0    5.0      8.530000      8.5300      8.5300
# 2   1514764860           1  229.0  13835.194000  14013.8000  13666.1100
# 3   1514764860           5   32.0      7.659600      7.6596      7.6567
# 4   1514764860           7    5.0     25.920000     25.9200     25.8740
# 5   1514764860           6  173.0    738.302500    746.0000    732.5100
# 6   1514764860           9  167.0    225.330000    227.7800    222.9800
# 8   1514764920           2   53.0   2374.553333   2400.9000   2354.2000
# 9   1514764920           0    7.0      8.530000      8.5300      8.5145
# 10  1514764920           1  235.0  13835.036000  14052.3000  13680.0000
# 11  1514764920           5   10.0      7.656800      7.6569      7.6567
# 12  1514764920           7    1.0     25.897000     25.8970     25.8970
# ...

# %%
new_crypto_df = new_crypto_df.fillna(0)
new_crypto_df
# Out:
#      timestamp  Asset_ID_x  Count          Open        High         Low  \
# 0   1514764860           2   40.0   2376.580000   2399.5000   2357.1400
# 1   1514764860           0    5.0      8.530000      8.5300      8.5300
# 2   1514764860           1  229.0  13835.194000  14013.8000  13666.1100
# 3   1514764860           5   32.0      7.659600      7.6596      7.6567
# 4   1514764860           7    5.0     25.920000     25.9200     25.8740
# 5   1514764860           6  173.0    738.302500    746.0000    732.5100
# 6   1514764860           9  167.0    225.330000    227.7800    222.9800
# 8   1514764920           2   53.0   2374.553333   2400.9000   2354.2000
# 9   1514764920           0    7.0      8.530000      8.5300      8.5145
# 10  1514764920           1  235.0  13835.036000  14052.3000  13680.0000
# 11  1514764920           5   10.0      7.656800      7.6569      7.6567
# 12  1514764920           7    1.0     25.897000     25.8970     25.8970
# ...

# %%
print("Number of rows with at least 1 NA value: ", (len(crypto_df)-len(new_crypto_df)))
# Out:
# Number of rows with at least 1 NA value:  24236793

# %%
new_crypto_df.notnull()
# Out:
#     timestamp  Asset_ID_x  Count  Open  High   Low  Close  Volume  VWAP  \
# 0        True        True   True  True  True  True   True    True  True
# 1        True        True   True  True  True  True   True    True  True
# 2        True        True   True  True  True  True   True    True  True
# 3        True        True   True  True  True  True   True    True  True
# 4        True        True   True  True  True  True   True    True  True
# 5        True        True   True  True  True  True   True    True  True
# 6        True        True   True  True  True  True   True    True  True
# 8        True        True   True  True  True  True   True    True  True
# 9        True        True   True  True  True  True   True    True  True
# 10       True        True   True  True  True  True   True    True  True
# 11       True        True   True  True  True  True   True    True  True
# 12       True        True   True  True  True  True   True    True  True
# ...

# %%
df.to_csv('new_crypto.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11668\91199097.py in <module>
# ----> 1 df.to_csv('new_crypto.csv')
#
# NameError: name 'df' is not defined

# %%
from pathlib import Path
import numpy as np
import pandas as pd

# %%
# Read in the data
# Note: The following data has been normalized between 0 and 1
data = Path('new_crypto.csv')
df = pd.read_csv(data)
df.head()
# Out:
#    Unnamed: 0   timestamp  Asset_ID  Count        Open        High  \
# 0           0  1514764860         2   40.0   2376.5800   2399.5000
# 1           1  1514764860         0    5.0      8.5300      8.5300
# 2           2  1514764860         1  229.0  13835.1940  14013.8000
# 3           3  1514764860         5   32.0      7.6596      7.6596
# 4           4  1514764860         7    5.0     25.9200     25.9200
#
#           Low       Close       Volume          VWAP    Target
# 0   2357.1400   2374.5900    19.233005   2373.116392 -0.004218
# 1      8.5300      8.5300    78.380000      8.530000 -0.014399
# 2  13666.1100  13850.1760    31.550062  13827.062093 -0.014643
# 3      7.6567      7.6576  6626.713370      7.657713 -0.013922
# 4     25.8740     25.8770   121.087310     25.891363 -0.008264

# %%
# Segment the features from the target
y = df["Target"]
X = df.drop(columns="Target")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11668\1195508690.py in <module>
#       1 # Segment the features from the target
# ----> 2 y = df["Target"]
#       3 X = df.drop(columns="Target")
#
# NameError: name 'df' is not defined

# %%
# Use the train_test_split function to create training and testing subsets
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, 
                                                    y, 
                                                    random_state=1, 
                                                    stratify=y)
X_train.shape
# Out:
# ValueErrorTraceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_50136\3425890325.py in <module>
#       5                                                     y,
#       6                                                     random_state=1,
# ----> 7                                                     stratify=y)
#       8 X_train.shape
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sklearn\model_selection\_split.py in train_test_split(test_size, train_size, random_state, shuffle, stratify, *arrays)
#    2439         cv = CVClass(test_size=n_test, train_size=n_train, random_state=random_state)
#    2440
# -> 2441         train, test = next(cv.split(X=arrays[0], y=stratify))
#    2442
#    2443     return list(
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sklearn\model_selection\_split.py in split(self, X, y, groups)
#    2020         to an integer.
#    2021         """
# -> 2022         y = check_array(y, ensure_2d=False, dtype=None)
# ...

# %% [markdown]
#  ## Create a SVM Model

# %%
# Instantiate a linear SVM model
from sklearn.svm import SVC
model = SVC(kernel='linear')

# %% [markdown]
# ## Fit(train) or model using the training data

# %%
# Fit the data
model.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11668\1123855073.py in <module>
#       1 # Fit the data
# ----> 2 model.fit(X_train, y_train)
#
# NameError: name 'X_train' is not defined
